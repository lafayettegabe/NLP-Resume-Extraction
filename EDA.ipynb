# %%
data_format = {
    "001"	:	{
	"content": "Govardhana K\nSenior Software Engineer\n\nBengaluru, Karnataka, Karnataka - Email me on Indeed: indeed.com/r/Govardhana-K/\nb2de315d95905b68\n\nTotal IT experience 5 Years 6 Months\nCloud Lending Solutions INC 4 Month • Salesforce Developer\nOracle 5 Years 2 Month • Core Java Developer\nLanguages Core Java, Go Lang\nOracle PL-SQL programming,\nSales Force Developer with APEX.\n\nDesignations & Promotions\n\nWilling to relocate: Anywhere\n\nWORK EXPERIENCE\n\nSenior Software Engineer\n\nCloud Lending Solutions -  Bangalore, Karnataka -\n\nJanuary 2018 to Present\n\nPresent\n\nSenior Consultant\n\nOracle -  Bangalore, Karnataka -\n\nNovember 2016 to December 2017\n\nStaff Consultant\n\nOracle -  Bangalore, Karnataka -\n\nJanuary 2014 to October 2016\n\nAssociate Consultant\n\nOracle -  Bangalore, Karnataka -\n\nNovember 2012 to December 2013\n\nEDUCATION\n\nB.E in Computer Science Engineering\n\nAdithya Institute of Technology -  Tamil Nadu\n\nSeptember 2008 to June 2012\n\nhttps://www.indeed.com/r/Govardhana-K/b2de315d95905b68?isid=rex-download&ikw=download-top&co=IN\nhttps://www.indeed.com/r/Govardhana-K/b2de315d95905b68?isid=rex-download&ikw=download-top&co=IN\n\n\nSKILLS\n\nAPEX. (Less than 1 year), Data Structures (3 years), FLEXCUBE (5 years), Oracle (5 years),\nAlgorithms (3 years)\n\nLINKS\n\nhttps://www.linkedin.com/in/govardhana-k-61024944/\n\nADDITIONAL INFORMATION\n\nTechnical Proficiency:\n\nLanguages: Core Java, Go Lang, Data Structures & Algorithms, Oracle\nPL-SQL programming, Sales Force with APEX.\nTools: RADTool, Jdeveloper, NetBeans, Eclipse, SQL developer,\nPL/SQL Developer, WinSCP, Putty\nWeb Technologies: JavaScript, XML, HTML, Webservice\n\nOperating Systems: Linux, Windows\nVersion control system SVN & Git-Hub\nDatabases: Oracle\nMiddleware: Web logic, OC4J\nProduct FLEXCUBE: Oracle FLEXCUBE Versions 10.x, 11.x and 12.x\n\nhttps://www.linkedin.com/in/govardhana-k-61024944/",
	"annotation": [{
		"label": ["Companies worked at"],
		"points": [{
			"start": 1749,
			"end": 1754,
			"text": "Oracle"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 1696,
			"end": 1701,
			"text": "Oracle"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 1417,
			"end": 1422,
			"text": "Oracle"
		}]
	}, {
		"label": ["Skills"],
		"points": [{
			"start": 1356,
			"end": 1792,
			"text": "Languages: Core Java, Go Lang, Data Structures & Algorithms, Oracle\nPL-SQL programming, Sales Force with APEX.\nTools: RADTool, Jdeveloper, NetBeans, Eclipse, SQL developer,\nPL/SQL Developer, WinSCP, Putty\nWeb Technologies: JavaScript, XML, HTML, Webservice\n\nOperating Systems: Linux, Windows\nVersion control system SVN & Git-Hub\nDatabases: Oracle\nMiddleware: Web logic, OC4J\nProduct FLEXCUBE: Oracle FLEXCUBE Versions 10.x, 11.x and 12.x"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 1209,
			"end": 1214,
			"text": "Oracle"
		}]
	}, {
		"label": ["Skills"],
		"points": [{
			"start": 1136,
			"end": 1247,
			"text": "APEX. (Less than 1 year), Data Structures (3 years), FLEXCUBE (5 years), Oracle (5 years),\nAlgorithms (3 years)\n"
		}]
	}, {
		"label": ["Graduation Year"],
		"points": [{
			"start": 928,
			"end": 931,
			"text": "2012"
		}]
	}, {
		"label": ["College Name"],
		"points": [{
			"start": 858,
			"end": 888,
			"text": "Adithya Institute of Technology"
		}]
	}, {
		"label": ["Degree"],
		"points": [{
			"start": 821,
			"end": 855,
			"text": "B.E in Computer Science Engineering"
		}]
	}, {
		"label": ["Graduation Year"],
		"points": [{
			"start": 787,
			"end": 790,
			"text": "2012"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 744,
			"end": 749,
			"text": "Oracle"
		}]
	}, {
		"label": ["Designation"],
		"points": [{
			"start": 722,
			"end": 741,
			"text": "Associate Consultant"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 658,
			"end": 663,
			"text": "Oracle"
		}]
	}, {
		"label": ["Designation"],
		"points": [{
			"start": 640,
			"end": 655,
			"text": "Staff Consultant"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 574,
			"end": 579,
			"text": "Oracle"
		}]
	}, {
		"label": ["Designation"],
		"points": [{
			"start": 555,
			"end": 572,
			"text": "Senior Consultant\n"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 470,
			"end": 492,
			"text": "Cloud Lending Solutions"
		}]
	}, {
		"label": ["Designation"],
		"points": [{
			"start": 444,
			"end": 468,
			"text": "Senior Software Engineer\n"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 308,
			"end": 313,
			"text": "Oracle"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 234,
			"end": 239,
			"text": "Oracle"
		}]
	}, {
		"label": ["Companies worked at"],
		"points": [{
			"start": 175,
			"end": 197,
			"text": "Cloud Lending Solutions"
		}]
	}, {
		"label": ["Email Address"],
		"points": [{
			"start": 93,
			"end": 136,
			"text": "indeed.com/r/Govardhana-K/\nb2de315d95905b68\n"
		}]
	}, {
		"label": ["Location"],
		"points": [{
			"start": 39,
			"end": 47,
			"text": "Bengaluru"
		}]
	}, {
		"label": ["Designation"],
		"points": [{
			"start": 13,
			"end": 37,
			"text": "Senior Software Engineer\n"
		}]
	}, {
		"label": ["Name"],
		"points": [{
			"start": 0,
			"end": 11,
			"text": "Govardhana K"
		}]
	}]
}
}

# %% [markdown]
# # Import Libraries

# %%
import json
import chardet
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %% [markdown]
# # 1.0: Understand the Data

# %%
# Read in the data
with open('data.json', 'rb') as f:
    data = f.read()

# Detect the encoding
encoding = chardet.detect(data)['encoding']

# Decode the data
data = data.decode(encoding)

# Load the data as JSON
data = json.loads(data)

# Create a DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
df.head()
# Out:
#                                                           001  \
# content     Govardhana K\nSenior Software Engineer\n\nBeng...
# annotation  [{'label': ['Companies worked at'], 'points': ...
#
#                                                           002  \
# content     Harini Komaravelli\nTest Analyst at Oracle, Hy...
# annotation  [{'label': ['Companies worked at'], 'points': ...
#
#                                                           003  \
# content     Hartej Kathuria\nData Analyst Intern - Oracle ...
# annotation  [{'label': ['Skills'], 'points': [{'start': 22...
#
#                                                           004  \
# content     Ijas Nizamuddin\nAssociate Consultant - State ...
# annotation  [{'label': ['Skills'], 'points': [{'start': 46...
#
#                                                           005  \
# content     Imgeeyaul Ansari\njava developer\n\nPune, Maha...
# annotation  [{'label': ['Skills'], 'points': [{'start': 18...
#
#                                                           006  \
# content     Jay Madhavi\nNavi Mumbai, Maharashtra - Email ...
# annotation  [{'label': ['Graduation Year'], 'points': [{'s...
#
#                                                           007  \
# content     Jitendra Babu\nFI/CO Consultant in Tech Mahind...
# annotation  [{'label': ['Graduation Year'], 'points': [{'s...
#
#                                                           008  \
# content     Jyotirbindu Patnaik\nAssociate consultant@SAP ...
# annotation  [{'label': ['Skills'], 'points': [{'start': 30...
#
#                                                           009  \
# content     Karthihayini C\nSystems Engineer - Infosys Lim...
# annotation  [{'label': ['Skills'], 'points': [{'start': 21...
#
#                                                           010  ...  \
# content     Karthik GV\nArchitect - Microsoft India\n\nHyd...  ...
# annotation  [{'label': ['Skills'], 'points': [{'start': 40...  ...
#
#                                                           191  \
# content     Pawan Nag\nMicrosoft Certified System Engineer...
# annotation  [{'label': ['Email Address'], 'points': [{'sta...
#
#                                                           192  \
# content     Shivam Sharma\nL1 Analyst in Microsoft project...
# annotation  [{'label': ['Skills'], 'points': [{'start': 13...
#
#                                                           193  \
# content     Gaikwad Dilip\nMicrosoft Dainamic Software Bil...
# annotation  [{'label': ['Skills'], 'points': [{'start': 95...
#
#                                                           194  \
# content     Moumita Mitra\n- Email me on Indeed: indeed.co...
# annotation  [{'label': ['Skills'], 'points': [{'start': 19...
#
#                                                           195  \
# content     Suman Biswas\nSAP UI5 Lead, Native HANA Develo...
# annotation  [{'label': ['Companies worked at'], 'points': ...
#
#                                                           196  \
# content     Mansi Thanki\nStudent\n\nJamnagar, Gujarat - E...
# annotation  [{'label': ['College Name'], 'points': [{'star...
#
#                                                           197  \
# content     Anil Kumar\nMicrosoft Azure (Basic Management)...
# annotation  [{'label': ['Location'], 'points': [{'start': ...
#
#                                                           198  \
# content     Siddharth Choudhary\nMicrosoft Office Suite - ...
# annotation  [{'label': ['Skills'], 'points': [{'start': 78...
#
#                                                           199  \
# content     Valarmathi Dhandapani\nInvestment Banking Oper...
# annotation  [{'label': ['Skills'], 'points': [{'start': 92...
#
#                                                           200
# content     Pradeep Kumar\nSecurity Analyst in Infosys - C...
# annotation  [{'label': ['Skills'], 'points': [{'start': 58...
#
# [2 rows x 200 columns]

# %%
# Invert rows and columns
df = df.T
df.head()
# Out:
#                                                content  \
# 001  Govardhana K\nSenior Software Engineer\n\nBeng...
# 002  Harini Komaravelli\nTest Analyst at Oracle, Hy...
# 003  Hartej Kathuria\nData Analyst Intern - Oracle ...
# 004  Ijas Nizamuddin\nAssociate Consultant - State ...
# 005  Imgeeyaul Ansari\njava developer\n\nPune, Maha...
#
#                                             annotation
# 001  [{'label': ['Companies worked at'], 'points': ...
# 002  [{'label': ['Companies worked at'], 'points': ...
# 003  [{'label': ['Skills'], 'points': [{'start': 22...
# 004  [{'label': ['Skills'], 'points': [{'start': 46...
# 005  [{'label': ['Skills'], 'points': [{'start': 18...

# %% [markdown]
# # 2.0: Text Block Classification

# %%
# Text Block Classification

# Raw text
raw_text = df["content"].tolist() # Its a list of strings

# Data cleaning: Clean the text data by removing irrelevant information, such as special characters, HTML tags, punctuation marks, stop words, and other unnecessary elements.

raw_text = [text.lower() for text in raw_text]
raw_text = [re.sub(r'[^a-zA-Z0-9\s]', '', text) for text in raw_text] # remove special characters
raw_text = [re.sub(r'[^\w\s]', '', text) for text in raw_text] # remove punctuation
raw_text = [re.sub(r'\d+', '', text) for text in raw_text] # remove numbers

stop_words = set(stopwords.words('english'))
raw_text = [[word for word in text.split() if word not in stop_words] for text in raw_text]

# Lemmatization
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in text]

raw_text = [lemmatize_text(text) for text in raw_text]

for i in range(len(raw_text)):
    raw_text[i] = ' '.join(raw_text[i])

df['cleaned_text'] = raw_text

# %%
# Its a resume that we are get the information from, so we need to remove the irrelevant information from the resume.

# Entity annotation
entity_annotation = df["annotation"].tolist()

labels = []
for i in range(len(entity_annotation)):
    for j in range(len(entity_annotation[i])):
        labels.append(entity_annotation[i][j]['label'][0])
        print(entity_annotation[i][j]['label'][0])
labels = list(set(labels))

entities = []
for i in range(len(entity_annotation)):
    for j in range(len(entity_annotation[i])):
        entities.append(entity_annotation[i][j]['points'][0]['text'])

start_positions = []
end_positions = []
for i in range(len(entity_annotation)):
    for j in range(len(entity_annotation[i])):
        start_positions.append(entity_annotation[i][j]['points'][0]['start'])
        end_positions.append(entity_annotation[i][j]['points'][0]['end'])

df2 = pd.DataFrame({'labels': labels, 'entities': entities, 'start_positions': start_positions, 'end_positions': end_positions})

df2.head()
# Out:
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Companies worked at
# Skills
# Graduation Year
# College Name
# Degree
# Graduation Year
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
#
# Companies worked at
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Graduation Year
# College Name
# Graduation Year
# College Name
# Graduation Year
# College Name
# Degree
# Graduation Year
# Location
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Email Address
# Location
# Companies worked at
# Skills
# Skills
# Graduation Year
# College Name
# Degree
# Graduation Year
# Graduation Year
# College Name
# Degree
# Graduation Year
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Email Address
# Location
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Skills
# Skills
# Skills
# College Name
# Degree
# Companies worked at
# Companies worked at
# Skills
# Email Address
# Companies worked at
# Skills
# Companies worked at
# Location
# Location
# Companies worked at
# Companies worked at
# Location
# Location
# Degree
# Location
# Companies worked at
# Email Address
# Location
# Companies worked at
# Designation
# Email Address
# Location
# Skills
# Location
# Degree
# College Name
# Companies worked at
# Designation
# Email Address
# Location
# Graduation Year
# College Name
# Degree
# Graduation Year
# Graduation Year
# Companies worked at
# Companies worked at
# Designation
# Location
# Companies worked at
# Designation
# Skills
# Skills
# Graduation Year
# College Name
# Degree
# Location
# Companies worked at
# Designation
# Location
# Companies worked at
# Designation
# Location
# Companies worked at
# Designation
# Companies worked at
# Designation
# Location
# Companies worked at
# Designation
# Location
# Companies worked at
# Designation
# Email Address
# Location
# Companies worked at
# Designation
# Skills
# Companies worked at
# Designation
# Location
# Companies worked at
# Designation
# Designation
# Designation
# Designation
# Location
# Companies worked at
# Designation
# Location
# Email Address
# Location
# Companies worked at
# Designation
# Designation
# Skills
# Skills
# College Name
# College Name
# Degree
# Graduation Year
# College Name
# Graduation Year
# College Name
# Degree
# College Name
# Degree
# Email Address
# Companies worked at
# Graduation Year
# Companies worked at
# Companies worked at
# Location
# Companies worked at
# Email Address
# Skills
# Skills
# Graduation Year
# College Name
# Degree
# Graduation Year
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Email Address
# Location
# Companies worked at
# Designation
# Graduation Year
# College Name
# Degree
# Graduation Year
# Location
# College Name
# Degree
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Location
# Years of Experience
# Email Address
# Location
# Companies worked at
# Years of Experience
# Email Address
# Skills
# College Name
# Degree
# Companies worked at
# Designation
# Email Address
# Location
# Skills
# College Name
# Degree
# Email Address
# Location
# Skills
# Skills
# Graduation Year
# College Name
# Graduation Year
# College Name
# Graduation Year
# College Name
# Degree
# Companies worked at
# Designation
# Location
# Email Address
# Location
# Designation
# Skills
# College Name
# Degree
# Graduation Year
# College Name
# Degree
# Designation
# Location
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Skills
# College Name
# Degree
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Email Address
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Designation
# Email Address
# Companies worked at
# Companies worked at
# Designation
# Designation
# Skills
# Graduation Year
# College Name
# Graduation Year
# College Name
# Degree
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Designation
# Email Address
# Location
# Designation
# Skills
# Graduation Year
# College Name
# Degree
# Designation
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Companies worked at
# Designation
# Designation
# Companies worked at
# Location
# Location
# Location
# Companies worked at
# Years of Experience
# Email Address
# Location
# Designation
# Companies worked at
# College Name
# Degree
# College Name
# Degree
# College Name
# Degree
# Email Address
# Designation
# Years of Experience
# Email Address
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Companies worked at
# Companies worked at
# Skills
# Skills
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Skills
# Skills
# Companies worked at
# Designation
# Designation
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Skills
# Graduation Year
# College Name
# Degree
# Skills
# Skills
# Companies worked at
# Companies worked at
# Companies worked at
# Skills
# Companies worked at
# Companies worked at
# Skills
# Skills
# Companies worked at
# Companies worked at
# Companies worked at
# Graduation Year
# Years of Experience
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Email Address
# Companies worked at
# Companies worked at
# Skills
# Skills
# Skills
# Skills
# Years of Experience
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Designation
# Companies worked at
# Companies worked at
# Companies worked at
# Companies worked at
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[88], line 9
#       7 for i in range(len(entity_annotation)-1):
#       8     for j in range(len(entity_annotation[i])-1):
# ----> 9         labels.append(entity_annotation[i][j]['label'][0])
#      10         print(entity_annotation[i][j]['label'][0])
#      11 labels = list(set(labels))
#
# IndexError: list index out of range

# %%
# Adaptative Segmentation
